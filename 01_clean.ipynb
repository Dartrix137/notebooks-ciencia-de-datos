# %%
#Importación de librerias
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.max_columns', 90)

# %%
# CWD = Current Working Directory
cwd = os.getcwd()
raw_dir = cwd + "/../data/raw/"
processed_dir = cwd + "/../data/processed/"

# %%
df = pd.read_csv(raw_dir + 'datos_unidos.csv')

# %%
df
# Out:
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                      CC          COLOMBIA           M           14/02/2004
# 1                      CC          COLOMBIA           F           12/09/2002
# 2                      TI          COLOMBIA           M           04/05/1999
# 3                      TI          COLOMBIA           F           17/04/2006
# 4                      TI          COLOMBIA           F           10/11/2005
# ...                   ...               ...         ...                  ...
# 173477                 TI          COLOMBIA           M           20/09/2002
# 173478                 TI          COLOMBIA           F           13/02/2001
# 173479                 TI          COLOMBIA           M           25/10/2002
# 173480                 TI          COLOMBIA           F           21/05/2002
# 173481                 TI          COLOMBIA           F           21/12/2002
#
# ...

# %% [markdown]
# A continuación se eliminan las variables que, al ser información de ubicación, personal o algún tipo de código de identificación, los cuales no aportan información relevante a cerca de lo que se quiere investigar.

# %%
#Se quitan columnas innecesarias
df= df.drop(columns=['ESTU_NACIONALIDAD', 'ESTU_GENERO','ESTU_PAIS_RESIDE','ESTU_TIPODOCUMENTO', 'COLE_NOMBRE_SEDE','ESTU_TIPOREMUNERACION', 'ESTU_FECHANACIMIENTO', 'COLE_MCPIO_UBICACION', 'ESTU_MCPIO_PRESENTACION','ESTU_DEPTO_PRESENTACION', 'ESTU_MCPIO_RESIDE', 'COLE_NOMBRE_ESTABLECIMIENTO','ESTU_CONSECUTIVO', 'ESTU_ESTUDIANTE', 'ESTU_DEPTO_RESIDE', 'ESTU_COD_RESIDE_DEPTO', 'ESTU_COD_RESIDE_MCPIO', 'COLE_COD_DANE_ESTABLECIMIENTO', 'COLE_CODIGO_ICFES', 'COLE_COD_DANE_SEDE', 'COLE_COD_DEPTO_UBICACION', 'COLE_DEPTO_UBICACION', 'ESTU_COD_MCPIO_PRESENTACION', 'PERIODO', 'COLE_COD_MCPIO_UBICACION', 'ESTU_COD_DEPTO_PRESENTACION', 'ESTU_ESTADOINVESTIGACION'])

# %%
#Se borran todos los registros vacíos
df = df.dropna()

# %%
df
# Out:
#        ESTU_TIENEETNIA                   FAMI_EDUCACIONPADRE  \
# 3                   Si        Técnica o tecnológica completa
# 4                   Si    Secundaria (Bachillerato) completa
# 9                   Si    Secundaria (Bachillerato) completa
# 11                  Si    Secundaria (Bachillerato) completa
# 13                  Si    Secundaria (Bachillerato) completa
# ...                ...                                   ...
# 173411              No  Secundaria (Bachillerato) incompleta
# 173412              No    Secundaria (Bachillerato) completa
# 173413              No    Secundaria (Bachillerato) completa
# 173414              No    Secundaria (Bachillerato) completa
# 173415              No        Educación profesional completa
#
#                          FAMI_EDUCACIONMADRE FAMI_ESTRATOVIVIENDA  \
# 3             Técnica o tecnológica completa            Estrato 1
# 4       Secundaria (Bachillerato) incompleta            Estrato 4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 126273 entries, 3 to 173415
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   ESTU_TIENEETNIA                126273 non-null  object
#  1   FAMI_EDUCACIONPADRE            126273 non-null  object
#  2   FAMI_EDUCACIONMADRE            126273 non-null  object
#  3   FAMI_ESTRATOVIVIENDA           126273 non-null  object
#  4   FAMI_PERSONASHOGAR             126273 non-null  object
#  5   FAMI_CUARTOSHOGAR              126273 non-null  object
#  6   FAMI_TIENEINTERNET             126273 non-null  object
#  7   FAMI_TIENECOMPUTADOR           126273 non-null  object
#  8   FAMI_TIENELAVADORA             126273 non-null  object
#  9   FAMI_TIENEHORNOMICROOGAS       126273 non-null  object
#  10  FAMI_TIENESERVICIOTV           126273 non-null  object
#  11  FAMI_TIENEAUTOMOVIL            126273 non-null  object
# ...

# %% [markdown]
# Guardar los datos ya limpios para iniciar el EDA

# %%
df.to_csv(processed_dir + 'datos_limpios.csv', index=False)
